# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from pandas import datetime
import numpy as np
from sklearn.metrics import mean_squared_error
# Out:
# <ipython-input-1-86acb80a78f2>:7: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
coca=pd.read_excel("/content/sample_data/CocaCola_Sales_Rawdata.xlsx")
coca.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
coca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
coca.describe().T
# Out:
#        count         mean         std          min          25%          50%  \
# Sales   42.0  2994.353308  977.930896  1547.818996  2159.714247  2782.376999
#
#            75%     max
# Sales  3609.25  5253.0

# %%
sns.distplot(coca.Sales)
# Out:
# <ipython-input-5-0d78891fc4ae>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coca.Sales)
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
coca.plot()
plt.show()

# %% [markdown]
# there is an upward trend with multiplicative seasonality

# %%
coca.hist()
plt.show()

# %%
coca.plot(kind='kde')
plt.show()

# %%
sns.boxplot(coca.Sales)
# Out:
# <Axes: >

# %%
lag_plot(coca.Sales)
plt.show()

# %%
plt.figure(figsize = (4,2))
plot_acf(coca.Sales,lags=41)
plt.show()

# %% [markdown]
# resampling , we have data of all quarter lets try to do downsampling (monthly wise data)

# %%
demo=coca.copy()

# %%
coca.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
coca.shape
# Out:
# (42, 2)

# %%
initial_val="NaN"
demo['quart']=initial_val[0:2]
demo['year']=0
for i in range(0,demo.shape[0]):
  temp=demo['Quarter'][i]
  demo['quart'][i]=temp[0:2]
  demo['year'][i]=temp[3:5]
# Out:
# <ipython-input-15-ced72c224dd0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demo['quart'][i]=temp[0:2]
# <ipython-input-15-ced72c224dd0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demo['year'][i]=temp[3:5]

# %%
demo.head()
# Out:
#   Quarter        Sales quart year
# 0   Q1_86  1734.827000    Q1   86
# 1   Q2_86  2244.960999    Q2   86
# 2   Q3_86  2533.804993    Q3   86
# 3   Q4_86  2154.962997    Q4   86
# 4   Q1_87  1547.818996    Q1   87

# %%
demo['QART']=demo['quart'].map({'Q1':'01-04','Q2':'01-07','Q3':'01-10','Q4':'01-01'})
for i in range(0,demo.shape[0]):
  date=demo['quart'][i]
  demo['year'][i]="19"+demo['year'][i]
demo['date']=demo['QART']+"-"+(demo['year'])

# %%
demo.drop('QART',axis=1,inplace=True)

# %%
demo.head()
# Out:
#   Quarter        Sales quart  year        date
# 0   Q1_86  1734.827000    Q1  1986  01-04-1986
# 1   Q2_86  2244.960999    Q2  1986  01-07-1986
# 2   Q3_86  2533.804993    Q3  1986  01-10-1986
# 3   Q4_86  2154.962997    Q4  1986  01-01-1986
# 4   Q1_87  1547.818996    Q1  1987  01-04-1987

# %%
cleaned_data=demo.drop(['Quarter','year'],axis=1)
cleaned_data.date = pd.to_datetime(cleaned_data.date)
cleaned_data.set_index('date',inplace=True)
cleaned_data.head()
# Out:
#                   Sales quart
# date
# 1986-01-04  1734.827000    Q1
# 1986-01-07  2244.960999    Q2
# 1986-01-10  2533.804993    Q3
# 1986-01-01  2154.962997    Q4
# 1987-01-04  1547.818996    Q1

# %%
#upsampling
upsample=cleaned_data.resample('m').mean()
upsample
# Out:
# <ipython-input-21-1fb6aba39b91>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   upsample=cleaned_data.resample('m').mean()
#                   Sales
# date
# 1986-01-31  2167.138997
# 1986-02-28          NaN
# 1986-03-31          NaN
# 1986-04-30          NaN
# 1986-05-31          NaN
# ...                 ...
# 1995-09-30          NaN
# 1995-10-31          NaN
# 1995-11-30          NaN
# 1995-12-31          NaN
# 1996-01-31  4723.500000
#
# [121 rows x 1 columns]

# %%
method=[ 'nearest', 'zero']
for data in method:
  print("******{}******".format(data))
  interpolated=upsample.interpolate(method=data)
  interpolated.plot()
  plt.show()
  print("________________________________________________________________")
# Out:
# ******nearest******
# ________________________________________________________________
# ******zero******
# ________________________________________________________________

# %% [markdown]
# from above upsampling we see that there is nothing much to derivate the trend,seasonality or any pattern

# %%
demo.head()
# Out:
#   Quarter        Sales quart  year        date
# 0   Q1_86  1734.827000    Q1  1986  01-04-1986
# 1   Q2_86  2244.960999    Q2  1986  01-07-1986
# 2   Q3_86  2533.804993    Q3  1986  01-10-1986
# 3   Q4_86  2154.962997    Q4  1986  01-01-1986
# 4   Q1_87  1547.818996    Q1  1987  01-04-1987

# %% [markdown]
# transformation

# %%
demo['t']=np.arange(1,43)
demo['t_squared']=demo['t']**2
demo['sales_log']=np.log(demo['Sales'])
demo['sales_sqrt']=np.sqrt(demo['Sales'])
demo.head()
# Out:
#   Quarter        Sales quart  year        date  t  t_squared  sales_log  \
# 0   Q1_86  1734.827000    Q1  1986  01-04-1986  1          1   7.458663
# 1   Q2_86  2244.960999    Q2  1986  01-07-1986  2          4   7.716443
# 2   Q3_86  2533.804993    Q3  1986  01-10-1986  3          9   7.837477
# 3   Q4_86  2154.962997    Q4  1986  01-01-1986  4         16   7.675529
# 4   Q1_87  1547.818996    Q1  1987  01-04-1987  5         25   7.344602
#
#    sales_sqrt
# 0   41.651254
# 1   47.381019
# 2   50.336915
# 3   46.421579
# 4   39.342331

# %%
plt.plot(demo['sales_log'])
plt.xlabel("log transformation")
plt.show()

# %%
plt.plot(demo['Sales'])
plt.xlabel("no transformation")
plt.show()

# %%
plt.plot(demo['sales_sqrt'])
plt.xlabel("sqrt transformation")
plt.show()

# %% [markdown]
# we can see in log and sqrt transformation trend is remaining as upward but in log transformation we able to capture the seasonility

# %% [markdown]
# MODEL building

# %%
#OHE to quarter column
demo=pd.get_dummies(demo,columns=['quart'])

# %%
#test train split
train=demo.head(32)
test=demo.tail(10)

# %%
train.tail()
# Out:
#    Quarter        Sales  year        date   t  t_squared  sales_log  \
# 27   Q4_92  3243.859993  1992  01-01-1992  28        784   8.084519
# 28   Q1_93  3056.000000  1993  01-04-1993  29        841   8.024862
# 29   Q2_93  3899.000000  1993  01-07-1993  30        900   8.268475
# 30   Q3_93  3629.000000  1993  01-10-1993  31        961   8.196712
# 31   Q4_93  3373.000000  1993  01-01-1993  32       1024   8.123558
#
#     sales_sqrt  quart_Q1  quart_Q2  quart_Q3  quart_Q4
# 27   56.954894         0         0         0         1
# 28   55.281100         1         0         0         0
# 29   62.441973         0         1         0         0
# 30   60.241182         0         0         1         0
# 31   58.077534         0         0         0         1

# %%
test.head()
# Out:
#    Quarter   Sales  year        date   t  t_squared  sales_log  sales_sqrt  \
# 32   Q1_94  3352.0  1994  01-04-1994  33       1089   8.117312   57.896459
# 33   Q2_94  4342.0  1994  01-07-1994  34       1156   8.376090   65.893854
# 34   Q3_94  4461.0  1994  01-10-1994  35       1225   8.403128   66.790718
# 35   Q4_94  4017.0  1994  01-01-1994  36       1296   8.298291   63.379808
# 36   Q1_95  3854.0  1995  01-04-1995  37       1369   8.256867   62.080593
#
#     quart_Q1  quart_Q2  quart_Q3  quart_Q4
# 32         1         0         0         0
# 33         0         1         0         0
# 34         0         0         1         0
# 35         0         0         0         1
# 36         1         0         0         0

# %%
#linear model
linear_model=smf.ols('Sales~t',data=train).fit()
linear_pred=linear_model.predict(test['t'])
linear_rmse=np.sqrt(mean_squared_error(test['Sales'],linear_pred))
linear_rmse
# Out:
# 752.9233932767116

# %%
#quadratic
quad_model=smf.ols('Sales~t+t_squared',data=train).fit()
quad_pred=quad_model.predict(test[['t','t_squared']])
quad_rmse=np.sqrt(mean_squared_error(test['Sales'],quad_pred))
quad_rmse
# Out:
# 457.735735540752

# %%
#exponential
expo_model=smf.ols('sales_log~t',data=train).fit()
expo_pred=expo_model.predict(test['t'])
expo_rmse=np.sqrt(mean_squared_error(test['sales_log'],expo_pred))
expo_rmse
# Out:
# 0.1353541149911446

# %%
#additive sea
add_seas_model=smf.ols('Sales~quart_Q1+quart_Q2+quart_Q3+quart_Q4',data=train).fit()
add_seas_pred=add_seas_model.predict(test[['quart_Q1','quart_Q2','quart_Q3','quart_Q4']])
add_seas_rmse=np.sqrt(mean_squared_error(test['Sales'],add_seas_pred))
add_seas_rmse
# Out:
# 1850.466546185835

# %%
#Additive Seasonality Quadratic
add_seas_quad_model=smf.ols('Sales~t+t_squared+quart_Q1+quart_Q2+quart_Q3+quart_Q4',data=train).fit()
add_seas_quad_pred=add_seas_quad_model.predict(test[['t','t_squared','quart_Q1','quart_Q2','quart_Q3','quart_Q4']])
add_seas_quad_rmse=np.sqrt(mean_squared_error(test['Sales'],add_seas_quad_pred))
add_seas_quad_rmse
# Out:
# 277.35107711285275

# %%
##Multiplicative Seasonality
mul_seas_model=smf.ols('sales_log~quart_Q1+quart_Q2+quart_Q3+quart_Q4',data=train).fit()
mul_seas_pred=mul_seas_model.predict(test[['quart_Q1','quart_Q2','quart_Q3','quart_Q4']])
mul_seas_rmse=np.sqrt(mean_squared_error(test['sales_log'],mul_seas_pred))
mul_seas_rmse
# Out:
# 0.5629197471132781

# %%
#Multiplicative quadratic Seasonality
mul_seas_quad_model=smf.ols('sales_log~t+t_squared+quart_Q1+quart_Q2+quart_Q3+quart_Q4',data=train).fit()
mul_seas_quad_pred=mul_seas_quad_model.predict(test[['t','t_squared','quart_Q1','quart_Q2','quart_Q3','quart_Q4']])
mul_seas_quad_rmse=np.sqrt(mean_squared_error(test['sales_log'],mul_seas_quad_pred))
mul_seas_quad_rmse
# Out:
# 0.1545092974569109

# %%
data={"MODEL":pd.Series(['linear model','quadratic','Exponential','additive sea',
                        'Additive Seasonality Quadratic' ,'Multiplicative Seasonality','Multiplicative quadratic Seasonality']),
      "RMSE SCORE":pd.Series([linear_rmse,quad_rmse,expo_rmse,add_seas_rmse,add_seas_quad_rmse,mul_seas_rmse,mul_seas_quad_rmse])}
data_rmse=pd.DataFrame(data)
data_rmse
# Out:
#                                   MODEL   RMSE SCORE
# 0                          linear model   752.923393
# 1                             quadratic   457.735736
# 2                           Exponential     0.135354
# 3                          additive sea  1850.466546
# 4        Additive Seasonality Quadratic   277.351077
# 5            Multiplicative Seasonality     0.562920
# 6  Multiplicative quadratic Seasonality     0.154509

# %% [markdown]
# from the above we observe that "Multiplicative quadratic Seasonality	" model is having low RMSE value as compared to others lets go with the Multiplicative quadratic Seasonality	model for prediction

# %%
print("predicted value    ","actual value   ")
print("__________________________________________")
for i in range(32,42):
  print(np.round(expo_pred[i],4),"            ",np.round(test['sales_log'][i],4))
# Out:
# predicted value     actual value
# __________________________________________
# 8.1827              8.1173
# 8.2045              8.3761
# 8.2263              8.4031
# 8.2481              8.2983
# 8.2699              8.2569
# 8.2917              8.5043
# 8.3135              8.496
# 8.3353              8.374
# 8.3571              8.3414
# 8.3789              8.5666

# %%
demo['expo_pred']=mul_seas_quad_model.predict(demo[['t','t_squared','quart_Q1','quart_Q2','quart_Q3','quart_Q4']])

# %%
demo
# Out:
#    Quarter        Sales  year        date   t  t_squared  sales_log  \
# 0    Q1_86  1734.827000  1986  01-04-1986   1          1   7.458663
# 1    Q2_86  2244.960999  1986  01-07-1986   2          4   7.716443
# 2    Q3_86  2533.804993  1986  01-10-1986   3          9   7.837477
# 3    Q4_86  2154.962997  1986  01-01-1986   4         16   7.675529
# 4    Q1_87  1547.818996  1987  01-04-1987   5         25   7.344602
# 5    Q2_87  2104.411995  1987  01-07-1987   6         36   7.651791
# 6    Q3_87  2014.362999  1987  01-10-1987   7         49   7.608058
# 7    Q4_87  1991.746998  1987  01-01-1987   8         64   7.596767
# 8    Q1_88  1869.049999  1988  01-04-1988   9         81   7.533186
# 9    Q2_88  2313.631996  1988  01-07-1988  10        100   7.746574
# 10   Q3_88  2128.320000  1988  01-10-1988  11        121   7.663088
# 11   Q4_88  2026.828999  1988  01-01-1988  12        144   7.614228
# 12   Q1_89  1910.603996  1989  01-04-1989  13        169   7.555175
# 13   Q2_89  2331.164993  1989  01-07-1989  14        196   7.754123
# 14   Q3_89  2206.549995  1989  01-10-1989  15        225   7.699185
# 15   Q4_89  2173.967995  1989  01-01-1989  16        256   7.684309
# 16   Q1_90  2148.278000  1990  01-04-1990  17        289   7.672422
# 17   Q2_90  2739.307999  1990  01-07-1990  18        324   7.915461
# 18   Q3_90  2792.753998  1990  01-10-1990  19        361   7.934783
# 19   Q4_90  2556.009995  1990  01-01-1990  20        400   7.846203
# 20   Q1_91  2480.973999  1991  01-04-1991  21        441   7.816407
# 21   Q2_91  3039.522995  1991  01-07-1991  22        484   8.019456
# 22   Q3_91  3172.115997  1991  01-10-1991  23        529   8.062154
# 23   Q4_91  2879.000999  1991  01-01-1991  24        576   7.965199
# 24   Q1_92  2772.000000  1992  01-04-1992  25        625   7.927324
# 25   Q2_92  3550.000000  1992  01-07-1992  26        676   8.174703
# 26   Q3_92  3508.000000  1992  01-10-1992  27        729   8.162801
# 27   Q4_92  3243.859993  1992  01-01-1992  28        784   8.084519
# 28   Q1_93  3056.000000  1993  01-04-1993  29        841   8.024862
# 29   Q2_93  3899.000000  1993  01-07-1993  30        900   8.268475
# 30   Q3_93  3629.000000  1993  01-10-1993  31        961   8.196712
# 31   Q4_93  3373.000000  1993  01-01-1993  32       1024   8.123558
# 32   Q1_94  3352.000000  1994  01-04-1994  33       1089   8.117312
# 33   Q2_94  4342.000000  1994  01-07-1994  34       1156   8.376090
# 34   Q3_94  4461.000000  1994  01-10-1994  35       1225   8.403128
# 35   Q4_94  4017.000000  1994  01-01-1994  36       1296   8.298291
# 36   Q1_95  3854.000000  1995  01-04-1995  37       1369   8.256867
# 37   Q2_95  4936.000000  1995  01-07-1995  38       1444   8.504311
# 38   Q3_95  4895.000000  1995  01-10-1995  39       1521   8.495970
# 39   Q4_95  4333.000000  1995  01-01-1995  40       1600   8.374015
# 40   Q1_96  4194.000000  1996  01-04-1996  41       1681   8.341410
# 41   Q2_96  5253.000000  1996  01-07-1996  42       1764   8.566555
#
#     sales_sqrt  quart_Q1  quart_Q2  quart_Q3  quart_Q4  expo_pred
# 0    41.651254         1         0         0         0   7.467483
# 1    47.381019         0         1         0         0   7.688410
# 2    50.336915         0         0         1         0   7.659692
# 3    46.421579         0         0         0         1   7.569577
# 4    39.342331         1         0         0         0   7.482375
# 5    45.873871         0         1         0         0   7.708551
# 6    44.881655         0         0         1         0   7.685082
# 7    44.628993         0         0         0         1   7.600216
# 8    43.232511         1         0         0         0   7.518264
# 9    48.100229         0         1         0         0   7.749688
# 10   46.133719         0         0         1         0   7.731469
# 11   45.020318         0         0         0         1   7.651852
# 12   43.710456         1         0         0         0   7.575149
# 13   48.282139         0         1         0         0   7.811822
# 14   46.973929         0         0         1         0   7.798852
# 15   46.625830         0         0         0         1   7.724484
# 16   46.349520         1         0         0         0   7.653030
# 17   52.338399         0         1         0         0   7.894953
# 18   52.846514         0         0         1         0   7.887231
# 19   50.556997         0         0         0         1   7.818112
# 20   49.809377         1         0         0         0   7.751907
# 21   55.131869         0         1         0         0   7.999079
# 22   56.321541         0         0         1         0   7.996607
# 23   53.656323         0         0         0         1   7.932737
# 24   52.649786         1         0         0         0   7.871781
# 25   59.581876         0         1         0         0   8.124202
# 26   59.228372         0         0         1         0   8.126979
# 27   56.954894         0         0         0         1   8.068358
# 28   55.281100         1         0         0         0   8.012651
# 29   62.441973         0         1         0         0   8.270321
# 30   60.241182         0         0         1         0   8.278347
# 31   58.077534         0         0         0         1   8.224976
# 32   57.896459         1         0         0         0   8.174518
# 33   65.893854         0         1         0         0   8.437437
# 34   66.790718         0         0         1         0   8.450712
# 35   63.379808         0         0         0         1   8.402589
# 36   62.080593         1         0         0         0   8.357381
# 37   70.256672         0         1         0         0   8.625549
# 38   69.964277         0         0         1         0   8.644073
# 39   65.825527         0         0         0         1   8.601199
# 40   64.761099         1         0         0         0   8.561240
# 41   72.477583         0         1         0         0   8.834657

# %%
demo[['sales_log','expo_pred']].reset_index(drop=True).plot()
# Out:
# <Axes: >

# %% [markdown]
# **ARIMA**

# %%
coca_new=coca.set_index('Quarter')

# %%
coca_new.head()
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996

# %%
coca_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42 entries, Q1_86 to Q2_96
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   42 non-null     float64
# dtypes: float64(1)
# memory usage: 672.0+ bytes

# %%
len(coca_new)
# Out:
# 42

# %%
train=coca_new[0:22]
test=coca_new[22:32]
validation=coca_new[32:43]
x=train.values
print("x values",x)
print("____________________________________________")
y=test.values
print("y values",y)
print("____________________________________________")
val=validation.values
print("validation values",val)
# Out:
# x values [[1734.82699966]
#  [2244.96099854]
#  [2533.80499268]
#  [2154.96299744]
#  [1547.81899643]
#  [2104.41199493]
#  [2014.36299896]
#  [1991.74699783]
#  [1869.04999924]
#  [2313.63199615]
#  [2128.31999969]
#  [2026.82899857]
#  [1910.60399628]
#  [2331.16499329]
#  [2206.54999542]
#  [2173.96799469]
#  [2148.27799988]
#  [2739.30799866]
#  [2792.7539978 ]
#  [2556.00999451]
#  [2480.97399902]
#  [3039.522995  ]]
# ____________________________________________
# y values [[3172.11599731]
#  [2879.00099945]
#  [2772.        ]
#  [3550.        ]
#  [3508.        ]
#  [3243.85999298]
#  [3056.        ]
#  [3899.        ]
#  [3629.        ]
#  [3373.        ]]
# ____________________________________________
# validation values [[3352.]
#  [4342.]
#  [4461.]
#  [4017.]
#  [3854.]
#  [4936.]
#  [4895.]
#  [4333.]
#  [4194.]
#  [5253.]]

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings

# %%
#ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X,arima_order):
  X=X.astype('float32')
  train_size=int(len(X)*0.5)
  train,test=X[0:train_size],X[train_size:]
  history=[x for x in train]
  #prediction
  prediction=list()
  for t in range(len(test)):
    model=ARIMA(history,order=arima_order)
  #model_fit
    model_fit=model.fit()
    yhat=model_fit.forecast()[0]
    prediction.append(yhat)
    history.append(test[t])
  rmse=np.sqrt(mean_squared_error(test,prediction))
  return rmse

# %%
#grid search for arima order p,d,q
def evaluate_model(dataset,p_val,d_val,q_val):
  dataset=dataset.astype('float32')
  best_score,best_cfg=float('inf'),None
  for p in p_val:
    for d in d_val:
      for q in q_val:
        order=(p,d,q)
        try:
          rmse=evaluate_arima_model(dataset,order)
          if rmse<best_score:
            best_score,best_cfg=rmse,order
            print('ARIMA%s RMSE=%.3f'%(order,rmse))
        except:
          continue
  print('Best ARIMA%s RMSE=%.3f'%(best_cfg,best_score))

# %%
#load_dataset
p_val=range(3,10)
d_val=range(2,10)
q_val=range(1,10)
warnings.filterwarnings("ignore")
evaluate_model(coca_new.values,p_val,d_val,q_val)
# Out:
# ARIMA(3, 2, 1) RMSE=173.999
# ARIMA(3, 3, 1) RMSE=171.835
# ARIMA(4, 2, 1) RMSE=162.159
# Best ARIMA(4, 2, 1) RMSE=162.159

# %%
p_val=range(3,10)
d_val=range(2,4)
q_val=range(1,3)
warnings.filterwarnings("ignore")
evaluate_model(coca_new.values,p_val,d_val,q_val)
# Out:
# ARIMA(3, 2, 1) RMSE=173.999
# ARIMA(3, 3, 1) RMSE=171.835
# ARIMA(4, 2, 1) RMSE=162.159
# Best ARIMA(4, 2, 1) RMSE=162.159
